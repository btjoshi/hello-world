# %% [markdown]
# # Linear regression model
#
# $\hat{y} \ = \ w_0 \ + \ w_1 x_1$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
housing = pd.read_csv('housing_sample.csv')
housing[:3]
# Out:
#   Neighborhood Exterior1st  YearBuilt  LotFrontage  GrLivArea  GarageArea  \
# 0      CollgCr     VinylSd       2003         65.0       1710         548
# 1      Veenker     MetalSd       1976         80.0       1262         460
# 2      CollgCr     VinylSd       2001         68.0       1786         608
#
#    BedroomAbvGr  FullBath  OverallQual HeatingQC  SalePrice
# 0             3         2            7        Ex     208500
# 1             3         2            6        Ex     181500
# 2             3         2            7        Ex     223500

# %%
fig, ax = plt.subplots(figsize=(10,5))
housing.plot(x='GrLivArea', y='SalePrice', kind='scatter', ax=ax);
ax.plot([0, 4000], [-200_000, 1_000_000], label='steep slope, low y-intercept')
ax.plot([0, 4000], [100_000, 200_000], label='flat slope, high y-intercept')
ax.legend()
#fig

# %% [markdown]
# Hence we have boundaries for intercept as [100,000, -200,000] and for slope [25, 300]

# %%
# Iterate over combinations to calculate RMSE
# Note the multiplication over all the values of X!!
X = housing['GrLivArea']
y = housing['SalePrice']
errors = {'w0': [], 'w1': [], 'rmse': []}
w0_range = range(-100_000, 125_000, 25_000)
w1_range = range(50, 300, 25)

for w0 in w0_range:
    for w1 in w1_range:
        y_pred = w0 + w1 * X
        error = y - y_pred
        rmse = np.sqrt((error ** 2).mean())
        errors['w0'].append(w0)
        errors['w1'].append(w1)
        errors['rmse'].append(rmse)

df_errors = pd.DataFrame(errors)
df_errors.sort_values('rmse').head(4)
# Out:
#        w0   w1          rmse
# 52  25000  100  56329.492140
# 43      0  125  57449.175994
# 71  75000   75  59030.490279
# 33 -25000  125  59159.272312

# %%
def simple_lr_model(X):
    return 25000 + 100 * X

X = np.array([0, 4000])
y_pred = simple_lr_model(X)
ax.plot(X, y_pred, color='red', label='best model', lw=3)
ax.set_title('Best linear model: $\hat{y} = 25,000 + 100 x_1$')
ax.legend
fig

# %%
def compute_r2(input_col, w0_range, w1_range):
    X = housing[input_col]
    y = housing['SalePrice']
    errors_r2 = {'w0':[], 'w1':[], 'r2':[]}
    variance = ((y - y.mean())**2).sum()
    for w0 in w0_range:
        for w1 in w1_range:
            y_pred = w0 + w1 * X
            sse = ((y - y_pred)**2).sum()
            r2 = (variance - sse) / variance
            errors_r2['w0'].append(w0)
            errors_r2['w1'].append(w1)
            errors_r2['r2'].append(r2)
    return pd.DataFrame(errors_r2)

df_errors_r2 = compute_r2('GrLivArea', w0_range, w1_range)
df_errors_r2.sort_values('r2', ascending=False).head(3)
# Out:
#        w0   w1        r2
# 52  25000  100  0.496889
# 43      0  125  0.476690
# 71  75000   75  0.447484

# %%
df_pivot = df_errors_r2.pivot(index='w0', columns='w1', values='r2').round(2)
df_pivot.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_3a15d7be_1f2f_11ea_845f_548ca0c0462erow0_col0 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_3a15d7be_1f2f_11ea_845f_548ca0c0462erow0_col1 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_3a15d7be_1f2f_11ea_845f_548ca0c0462erow0_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_3a15d7be_1f2f_11ea_845f_548ca0c0462erow0_col3 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_3a15d7be_1f2f_11ea_845f_548ca0c0462erow0_col4 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_3a15d7be_1f2f_11ea_845f_548ca0c0462erow0_col5 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_3a15d7be_1f2f_11ea_845f_548ca0c0462erow0_col6 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
# ...

# %%
fig2, ax2 = plt.subplots(figsize=(10,5))
housing.plot(x='GarageArea', y='SalePrice', kind='scatter', ax=ax2)
ax2.plot([0, 1200], [-100_000, 1_000_000], label='steep slope, low y-intercept')
ax2.plot([0, 1200], [0, 100_000], label='flat slope, high y-intercept')
ax2.legend()
#fig2

# %%
w0_range = range(-100_000, 125_000, 25_000)
w1_range = range(50, 300, 25)
df_errors_r2 = compute_r2('GarageArea', w0_range, w1_range)
df_errors_r2.sort_values('r2', ascending=False).head(3)
# Out:
#         w0   w1        r2
# 77   75000  225  0.388307
# 69   50000  275  0.374937
# 85  100000  175  0.364883

# %%
def simple_lr_model2(X):
    return 75000 + 225 * X

X = np.array([0, 1200])
y_pred = simple_lr_model2(X)
ax2.plot(X, y_pred, color='red', label='best model', lw=3)
ax2.set_title('Best linear model: $\hat{y} = 75,000 + 225 x_1$')
ax2.legend
fig2

# %%
# The scikit-learn estimator
X = housing[['GrLivArea']]  # need 2 D input
y = housing['SalePrice']
# import the estimator
from sklearn.linear_model import LinearRegression
# Instantiate or construct a new instance of the regressior
lr = LinearRegression()
# fit the model
lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
new_data = np.array([[500], [1000], [3000], [5000]])
lr.predict(new_data).round(-3)
# Out:
# array([ 72000., 126000., 340000., 554000.])

# %%
lr.score(X, y)
# Out:
# 0.5021486502718042

# %%
# Multiple Linear Regression
X = housing[['GrLivArea', 'GarageArea', 'FullBath']]
y = housing['SalePrice']
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lr.coef_
# Out:
# array([   70.0661081 ,   132.12662295, 17942.89605841])

# %%
y_pred = lr.predict(X[:10]).round(-3)
fig, ax = plt.subplots(figsize=(12,5))
#ax.scatter(np.arrange(10), y_pred, label='predicted')  ## spellerror!
ax.scatter(np.arange(10), y_pred, label='predicted')
ax.scatter(np.arange(10), y.head(10), label='actual')
ax.legend()
ax.set_title('Actual vs Predicted for first 10 rows')
ax.set_ylabel('Sale Price')
ax.set_xticks([])
lr.score(X, y)
# Out:
# 0.6198706918364121

# %%
housing[:2]
# Out:
#   Neighborhood Exterior1st  YearBuilt  LotFrontage  GrLivArea  GarageArea  \
# 0      CollgCr     VinylSd       2003         65.0       1710         548
# 1      Veenker     MetalSd       1976         80.0       1262         460
#
#    BedroomAbvGr  FullBath  OverallQual HeatingQC  SalePrice
# 0             3         2            7        Ex     208500
# 1             3         2            6        Ex     181500

# %%
X2 = housing[['GrLivArea', 'GarageArea']]
X3 = housing[['GrLivArea', 'GarageArea', 'BedroomAbvGr']]
X4 = housing[['GrLivArea', 'GarageArea', 'BedroomAbvGr', 'FullBath']]
X5 = housing[['GrLivArea', 'GarageArea', 'BedroomAbvGr', 'FullBath', 'OverallQual']]
lr2 = LinearRegression()
lr2.fit(X2, y)
lr2.score(X2, y)
# Out:
# 0.6107742041987958

# %%
lr3 = LinearRegression()
lr3.fit(X3, y)
lr3.score(X3, y)
# Out:
# 0.7464729241211185

# %%
lr4 = LinearRegression()
lr4.fit(X4, y)
lr4.score(X4, y)
# Out:
# 0.6493897267876736

# %%
lr5 = LinearRegression()
lr5.fit(X5, y)
lr5.score(X5, y)
# Out:
# 0.7464729241211185

# %%
x = np.arange(-5, 5, .2)
y = 8 - (12 * x) + (5 * x ** 2) + (2 * x ** 3)
fig, ax = plt.subplots(figsize=(12,6))
ax.scatter(x, y)

# %%
X = np.column_stack((x, x**2, x**3))
lr = LinearRegression()
lr.fit(X, y)
y_pred = lr.predict(X)
ax.plot(x, y_pred, color='red', linewidth=3)
ax.set_title('Perfect_fit')
fig

# %%
lr.coef_
# Out:
# array([-12.,   5.,   2.])

# %%
# K Nearest Neighbours KNN
df = housing[['GrLivArea', 'GarageArea', 'SalePrice']].copy()
# estimating nearest distance for new livArea 2500 and Garage Area 800 
df['distance'] = np.sqrt((df['GrLivArea'] - 2500) ** 2 + (df['GarageArea'] - 800) ** 2 )
#df.neigbors = df.smallest(5, 'distance')  spellerror!!
df_neighbors = df.nsmallest(5, 'distance')
df_neighbors
# Out:
#       GrLivArea  GarageArea  SalePrice   distance
# 1032       2520         796     310000  20.396078
# 1302       2526         844     290000  51.107729
# 759        2531         752     290000  57.140179
# 65         2473         852     317000  58.591808
# 321        2468         872     354000  78.790862

# %%
df_neighbors['SalePrice'].mean()
# Out:
# 312200.0

# %%
# custom KNN function with plot

import matplotlib.pyplot as plt

def plot_neighbors(sq_foot, sq_foot_garage, k):
    df = housing[['GrLivArea', 'GarageArea', 'SalePrice']].copy()
    df['distance'] = np.sqrt((df['GrLivArea'] - sq_foot) ** 2 + (df['GarageArea'] - sq_foot_garage) ** 2)
    df_neighbors = df.nsmallest(k, 'distance')
    mean = df_neighbors['SalePrice'].mean()
    
    ax = df.plot(x='GrLivArea', y='GarageArea', kind='scatter', figsize=(16,5))
    df_neighbors.plot(x='GrLivArea', y='GarageArea', kind='scatter', color='red', ax=ax, label=f'{k} neighbors')
    ax.scatter([sq_foot], [sq_foot_garage], color='green', s=60, label='Predicted Value')
    ax.set_title(f'{k} nearest neighbors of {sq_foot} sq ft and {sq_foot_garage} basement sq ft predict sale price {mean}')
    ax.legend()

# %%
plot_neighbors(1000, 700, 10)

# %% [markdown]
# ####
