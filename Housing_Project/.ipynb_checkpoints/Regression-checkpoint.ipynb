# %% [markdown]
# # Linear regression model
#
# $\hat{y} \ = \ w_0 \ + \ w_1 x_1$

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
housing = pd.read_csv('housing_sample.csv')
housing[:3]
# Out:
#   Neighborhood Exterior1st  YearBuilt  LotFrontage  GrLivArea  GarageArea  \
# 0      CollgCr     VinylSd       2003         65.0       1710         548
# 1      Veenker     MetalSd       1976         80.0       1262         460
# 2      CollgCr     VinylSd       2001         68.0       1786         608
#
#    BedroomAbvGr  FullBath  OverallQual HeatingQC  SalePrice
# 0             3         2            7        Ex     208500
# 1             3         2            6        Ex     181500
# 2             3         2            7        Ex     223500

# %%
fig, ax = plt.subplots(figsize=(10,5))
housing.plot(x='GrLivArea', y='SalePrice', kind='scatter', ax=ax);
ax.plot([0, 4000], [-200_000, 1_000_000], label='steep slope, low y-intercept')
ax.plot([0, 4000], [100_000, 200_000], label='flat slope, high y-intercept')
ax.legend()
#fig

# %% [markdown]
# Hence we have boundaries for intercept as [100,000, -200,000] and for slope [25, 300]

# %%
# Iterate over combinations to calculate RMSE
# Note the multiplication over all the values of X!!
X = housing['GrLivArea']
y = housing['SalePrice']
errors = {'w0': [], 'w1': [], 'rmse': []}
w0_range = range(-100_000, 125_000, 25_000)
w1_range = range(50, 300, 25)

for w0 in w0_range:
    for w1 in w1_range:
        y_pred = w0 + w1 * X
        error = y - y_pred
        rmse = np.sqrt((error ** 2).mean())
        errors['w0'].append(w0)
        errors['w1'].append(w1)
        errors['rmse'].append(rmse)

df_errors = pd.DataFrame(errors)
df_errors.sort_values('rmse').head(4)
# Out:
#        w0   w1          rmse
# 52  25000  100  56329.492140
# 43      0  125  57449.175994
# 71  75000   75  59030.490279
# 33 -25000  125  59159.272312

# %%
def simple_lr_model(X):
    return 25000 + 100 * X

X = np.array([0, 4000])
y_pred = simple_lr_model(X)
ax.plot(X, y_pred, color='red', label='best model', lw=3)
ax.set_title('Best linear model: $\hat{y} = 25,000 + 100 x_1$')
ax.legend
fig

# %%
def compute_r2(input_col, w0_range, w1_range):
    X = housing[input_col]
    y = housing['SalePrice']
    errors_r2 = {'w0':[], 'w1':[], 'r2':[]}
    variance = ((y - y.mean())**2).sum()
    for w0 in w0_range:
        for w1 in w1_range:
            y_pred = w0 + w1 * X
            sse = ((y - y_pred)**2).sum()
            r2 = (variance - sse) / variance
            errors_r2['w0'].append(w0)
            errors_r2['w1'].append(w1)
            errors_r2['r2'].append(r2)
    return pd.DataFrame(errors_r2)

df_errors_r2 = compute_r2('GrLivArea', w0_range, w1_range)
df_errors_r2.sort_values('r2', ascending=False).head(3)
# Out:
#        w0   w1        r2
# 52  25000  100  0.496889
# 43      0  125  0.476690
# 71  75000   75  0.447484

# %%
df_pivot = df_errors_r2.pivot(index='w0', columns='w1', values='r2').round(2)
df_pivot.style.background_gradient(cmap='coolwarm', axis=None)
# Out:
# <style  type="text/css" >
#     #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col0 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col1 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col2 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col3 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col4 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col5 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col6 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col7 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col8 {
#             background-color:  #de614d;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow0_col9 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col0 {
#             background-color:  #f6a385;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col1 {
#             background-color:  #e8765c;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col2 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col3 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col4 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col5 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col6 {
#             background-color:  #c12b30;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col7 {
#             background-color:  #d44e41;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col8 {
#             background-color:  #e9785d;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow1_col9 {
#             background-color:  #f6a586;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col0 {
#             background-color:  #ef886b;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col1 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col2 {
#             background-color:  #c73635;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col3 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col4 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col5 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col6 {
#             background-color:  #cb3e38;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col7 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col8 {
#             background-color:  #f29072;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow2_col9 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col0 {
#             background-color:  #e36b54;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col1 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col2 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col4 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col5 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col6 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col7 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col8 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow3_col9 {
#             background-color:  #edd2c3;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col0 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col1 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col2 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col4 {
#             background-color:  #bb1b2c;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col5 {
#             background-color:  #cc403a;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col6 {
#             background-color:  #e26952;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col7 {
#             background-color:  #f39778;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col8 {
#             background-color:  #f5c4ac;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow4_col9 {
#             background-color:  #d6dce4;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col0 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col1 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col3 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col4 {
#             background-color:  #c43032;
#             color:  #f1f1f1;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col5 {
#             background-color:  #d85646;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col6 {
#             background-color:  #ee8468;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col7 {
#             background-color:  #f7b194;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col8 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_c258d49e_1e9f_11ea_a198_548ca0c0462erow5_col9 {
#             background-color:  #b6cefa;
#             color:  #000000;
